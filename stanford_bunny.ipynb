# %%
import time
import cv2
import numpy as np
import os
os.environ["OPENCV_IO_ENABLE_OPENEXR"]="1"
from tsdf import TSDF, get_volume_bounds

# %% [markdown]
# ## Data Processing

# %%
data_folder = "data/stanford_bunny/"
cam_intrinsics_file = data_folder + "cam.txt"
frame_color_img_file = data_folder + "rgb_{:04d}.png"
frame_depth_img_file = data_folder + "depth_{:04d}.exr"
frame_pose_file = data_folder + "pose_{:04d}.txt"
frames_count = 500
cam_to_motion_T = np.diag([1, 1, 1, 1])
output_mesh_file = "bunny_outputs/bunny_mesh.ply"
output_pc_file = "bunny_outputs/bunny_pc.ply"

# %%
def process_data():
    frame_color_imgs = []
    frame_depth_imgs = []
    frame_poses = []

    # read the data
    for i in range(frames_count):
        color_img = cv2.imread(frame_color_img_file.format(i))
        color_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2RGB)
        # flip image horizontally
        color_img = cv2.flip(color_img, 1)
        frame_color_imgs.append(color_img)

        depth_img = cv2.imread(frame_depth_img_file.format(i), cv2.IMREAD_ANYCOLOR | cv2.IMREAD_ANYDEPTH)
        depth_img = cv2.cvtColor(depth_img, cv2.COLOR_BGR2GRAY)
        depth_img = cv2.flip(depth_img, 1)
        depth_img[depth_img == 65504] = 0
        
        frame_depth_imgs.append(depth_img)
        frame_pose = np.loadtxt(frame_pose_file.format(i)) @ cam_to_motion_T
        frame_poses.append(frame_pose)
    return frame_color_imgs, frame_depth_imgs, frame_poses

# %%
frame_color_imgs, frame_depth_imgs, frame_poses = process_data()
cam_intrinsics = np.loadtxt(cam_intrinsics_file)

# %%
rgb_img = frame_color_imgs[0]
depth_img = frame_depth_imgs[0]
p = frame_poses[0]

import matplotlib.pyplot as plt
# plot the first frame
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(rgb_img)
plt.title("RGB Image")
plt.axis("off")
plt.subplot(1, 2, 2)
plt.imshow(depth_img, cmap="gray")
plt.title("Depth Image")
plt.axis("off")
plt.show()

# %% [markdown]
# ## TSDF Construction

# %%
tsdf_voxel_size = 0.02  # 2cm
tsdf_trunc_margin =5*tsdf_voxel_size  # 10cm

volume_bounds = get_volume_bounds(
    frames_count, frame_depth_imgs, frame_poses, cam_intrinsics
)
# Out:
# Volume bounds:
# [[-3.06000018  3.06000018]
#  [-3.05971408  3.05971408]
#  [-3.05971408  3.05971408]]

# %%
tsdf_obj = TSDF(
    volume_bounds,
    voxel_size=tsdf_voxel_size,
    trunc_margin=tsdf_trunc_margin,
    run_on_gpu=True,
)
start_time = time.time()
tsdf_obj.build_tsdf(
    frames_count, frame_color_imgs, frame_depth_imgs, frame_poses, cam_intrinsics
)
end_time = time.time()
print("Time: ", end_time - start_time, "seconds")
print("FPS: ", frames_count / (end_time - start_time))
# Out:
# Volume dims:  [307 306 306]
# Using GPU:  NVIDIA GeForce RTX 3090
# Maximum number of threads per block: 1024
# Maximum block dimension: 1024, 1024, 64
# Maximum grid dimension: 2147483647, 65535, 65535
# Block size: (1024, 1, 1), Grid size: (28073, 1, 1)
# Fusing frame 0
# Fusing frame 1
# Fusing frame 2
# Fusing frame 3
# Fusing frame 4
# Fusing frame 5
# Fusing frame 6
# Fusing frame 7
# Fusing frame 8
# Fusing frame 9
# Fusing frame 10
# Fusing frame 11
# Fusing frame 12
# Fusing frame 13
# Fusing frame 14
# Fusing frame 15
# Fusing frame 16
# Fusing frame 17
# Fusing frame 18
# Fusing frame 19
# Fusing frame 20
# Fusing frame 21
# Fusing frame 22
# Fusing frame 23
# Fusing frame 24
# Fusing frame 25
# Fusing frame 26
# Fusing frame 27
# Fusing frame 28
# Fusing frame 29
# Fusing frame 30
# Fusing frame 31
# Fusing frame 32
# Fusing frame 33
# Fusing frame 34
# Fusing frame 35
# Fusing frame 36
# Fusing frame 37
# Fusing frame 38
# Fusing frame 39
# Fusing frame 40
# Fusing frame 41
# Fusing frame 42
# Fusing frame 43
# Fusing frame 44
# Fusing frame 45
# Fusing frame 46
# Fusing frame 47
# Fusing frame 48
# Fusing frame 49
# Fusing frame 50
# Fusing frame 51
# Fusing frame 52
# Fusing frame 53
# Fusing frame 54
# Fusing frame 55
# Fusing frame 56
# Fusing frame 57
# Fusing frame 58
# Fusing frame 59
# Fusing frame 60
# Fusing frame 61
# Fusing frame 62
# Fusing frame 63
# Fusing frame 64
# Fusing frame 65
# Fusing frame 66
# Fusing frame 67
# Fusing frame 68
# Fusing frame 69
# Fusing frame 70
# Fusing frame 71
# Fusing frame 72
# Fusing frame 73
# Fusing frame 74
# Fusing frame 75
# Fusing frame 76
# Fusing frame 77
# Fusing frame 78
# Fusing frame 79
# Fusing frame 80
# Fusing frame 81
# Fusing frame 82
# Fusing frame 83
# Fusing frame 84
# Fusing frame 85
# Fusing frame 86
# Fusing frame 87
# Fusing frame 88
# Fusing frame 89
# Fusing frame 90
# Fusing frame 91
# Fusing frame 92
# Fusing frame 93
# Fusing frame 94
# Fusing frame 95
# Fusing frame 96
# Fusing frame 97
# Fusing frame 98
# Fusing frame 99
# Fusing frame 100
# Fusing frame 101
# Fusing frame 102
# Fusing frame 103
# Fusing frame 104
# Fusing frame 105
# Fusing frame 106
# Fusing frame 107
# Fusing frame 108
# Fusing frame 109
# Fusing frame 110
# Fusing frame 111
# Fusing frame 112
# Fusing frame 113
# Fusing frame 114
# Fusing frame 115
# Fusing frame 116
# Fusing frame 117
# Fusing frame 118
# Fusing frame 119
# Fusing frame 120
# Fusing frame 121
# Fusing frame 122
# Fusing frame 123
# Fusing frame 124
# Fusing frame 125
# Fusing frame 126
# Fusing frame 127
# Fusing frame 128
# Fusing frame 129
# Fusing frame 130
# Fusing frame 131
# Fusing frame 132
# Fusing frame 133
# Fusing frame 134
# Fusing frame 135
# Fusing frame 136
# Fusing frame 137
# Fusing frame 138
# Fusing frame 139
# Fusing frame 140
# Fusing frame 141
# Fusing frame 142
# Fusing frame 143
# Fusing frame 144
# Fusing frame 145
# Fusing frame 146
# Fusing frame 147
# Fusing frame 148
# Fusing frame 149
# Fusing frame 150
# Fusing frame 151
# Fusing frame 152
# Fusing frame 153
# Fusing frame 154
# Fusing frame 155
# Fusing frame 156
# Fusing frame 157
# Fusing frame 158
# Fusing frame 159
# Fusing frame 160
# Fusing frame 161
# Fusing frame 162
# Fusing frame 163
# Fusing frame 164
# Fusing frame 165
# Fusing frame 166
# Fusing frame 167
# Fusing frame 168
# Fusing frame 169
# Fusing frame 170
# Fusing frame 171
# Fusing frame 172
# Fusing frame 173
# Fusing frame 174
# Fusing frame 175
# Fusing frame 176
# Fusing frame 177
# Fusing frame 178
# Fusing frame 179
# Fusing frame 180
# Fusing frame 181
# Fusing frame 182
# Fusing frame 183
# Fusing frame 184
# Fusing frame 185
# Fusing frame 186
# Fusing frame 187
# Fusing frame 188
# Fusing frame 189
# Fusing frame 190
# Fusing frame 191
# Fusing frame 192
# Fusing frame 193
# Fusing frame 194
# Fusing frame 195
# Fusing frame 196
# Fusing frame 197
# Fusing frame 198
# Fusing frame 199
# Fusing frame 200
# Fusing frame 201
# Fusing frame 202
# Fusing frame 203
# Fusing frame 204
# Fusing frame 205
# Fusing frame 206
# Fusing frame 207
# Fusing frame 208
# Fusing frame 209
# Fusing frame 210
# Fusing frame 211
# Fusing frame 212
# Fusing frame 213
# Fusing frame 214
# Fusing frame 215
# Fusing frame 216
# Fusing frame 217
# Fusing frame 218
# Fusing frame 219
# Fusing frame 220
# Fusing frame 221
# Fusing frame 222
# Fusing frame 223
# Fusing frame 224
# Fusing frame 225
# Fusing frame 226
# Fusing frame 227
# Fusing frame 228
# Fusing frame 229
# Fusing frame 230
# Fusing frame 231
# Fusing frame 232
# Fusing frame 233
# Fusing frame 234
# Fusing frame 235
# Fusing frame 236
# Fusing frame 237
# Fusing frame 238
# Fusing frame 239
# Fusing frame 240
# Fusing frame 241
# Fusing frame 242
# Fusing frame 243
# Fusing frame 244
# Fusing frame 245
# Fusing frame 246
# Fusing frame 247
# Fusing frame 248
# Fusing frame 249
# Fusing frame 250
# Fusing frame 251
# Fusing frame 252
# Fusing frame 253
# Fusing frame 254
# Fusing frame 255
# Fusing frame 256
# Fusing frame 257
# Fusing frame 258
# Fusing frame 259
# Fusing frame 260
# Fusing frame 261
# Fusing frame 262
# Fusing frame 263
# Fusing frame 264
# Fusing frame 265
# Fusing frame 266
# Fusing frame 267
# Fusing frame 268
# Fusing frame 269
# Fusing frame 270
# Fusing frame 271
# Fusing frame 272
# Fusing frame 273
# Fusing frame 274
# Fusing frame 275
# Fusing frame 276
# Fusing frame 277
# Fusing frame 278
# Fusing frame 279
# Fusing frame 280
# Fusing frame 281
# Fusing frame 282
# Fusing frame 283
# Fusing frame 284
# Fusing frame 285
# Fusing frame 286
# Fusing frame 287
# Fusing frame 288
# Fusing frame 289
# Fusing frame 290
# Fusing frame 291
# Fusing frame 292
# Fusing frame 293
# Fusing frame 294
# Fusing frame 295
# Fusing frame 296
# Fusing frame 297
# Fusing frame 298
# Fusing frame 299
# Fusing frame 300
# Fusing frame 301
# Fusing frame 302
# Fusing frame 303
# Fusing frame 304
# Fusing frame 305
# Fusing frame 306
# Fusing frame 307
# Fusing frame 308
# Fusing frame 309
# Fusing frame 310
# Fusing frame 311
# Fusing frame 312
# Fusing frame 313
# Fusing frame 314
# Fusing frame 315
# Fusing frame 316
# Fusing frame 317
# Fusing frame 318
# Fusing frame 319
# Fusing frame 320
# Fusing frame 321
# Fusing frame 322
# Fusing frame 323
# Fusing frame 324
# Fusing frame 325
# Fusing frame 326
# Fusing frame 327
# Fusing frame 328
# Fusing frame 329
# Fusing frame 330
# Fusing frame 331
# Fusing frame 332
# Fusing frame 333
# Fusing frame 334
# Fusing frame 335
# Fusing frame 336
# Fusing frame 337
# Fusing frame 338
# Fusing frame 339
# Fusing frame 340
# Fusing frame 341
# Fusing frame 342
# Fusing frame 343
# Fusing frame 344
# Fusing frame 345
# Fusing frame 346
# Fusing frame 347
# Fusing frame 348
# Fusing frame 349
# Fusing frame 350
# Fusing frame 351
# Fusing frame 352
# Fusing frame 353
# Fusing frame 354
# Fusing frame 355
# Fusing frame 356
# Fusing frame 357
# Fusing frame 358
# Fusing frame 359
# Fusing frame 360
# Fusing frame 361
# Fusing frame 362
# Fusing frame 363
# Fusing frame 364
# Fusing frame 365
# Fusing frame 366
# Fusing frame 367
# Fusing frame 368
# Fusing frame 369
# Fusing frame 370
# Fusing frame 371
# Fusing frame 372
# Fusing frame 373
# Fusing frame 374
# Fusing frame 375
# Fusing frame 376
# Fusing frame 377
# Fusing frame 378
# Fusing frame 379
# Fusing frame 380
# Fusing frame 381
# Fusing frame 382
# Fusing frame 383
# Fusing frame 384
# Fusing frame 385
# Fusing frame 386
# Fusing frame 387
# Fusing frame 388
# Fusing frame 389
# Fusing frame 390
# Fusing frame 391
# Fusing frame 392
# Fusing frame 393
# Fusing frame 394
# Fusing frame 395
# Fusing frame 396
# Fusing frame 397
# Fusing frame 398
# Fusing frame 399
# Fusing frame 400
# Fusing frame 401
# Fusing frame 402
# Fusing frame 403
# Fusing frame 404
# Fusing frame 405
# Fusing frame 406
# Fusing frame 407
# Fusing frame 408
# Fusing frame 409
# Fusing frame 410
# Fusing frame 411
# Fusing frame 412
# Fusing frame 413
# Fusing frame 414
# Fusing frame 415
# Fusing frame 416
# Fusing frame 417
# Fusing frame 418
# Fusing frame 419
# Fusing frame 420
# Fusing frame 421
# Fusing frame 422
# Fusing frame 423
# Fusing frame 424
# Fusing frame 425
# Fusing frame 426
# Fusing frame 427
# Fusing frame 428
# Fusing frame 429
# Fusing frame 430
# Fusing frame 431
# Fusing frame 432
# Fusing frame 433
# Fusing frame 434
# Fusing frame 435
# Fusing frame 436
# Fusing frame 437
# Fusing frame 438
# Fusing frame 439
# Fusing frame 440
# Fusing frame 441
# Fusing frame 442
# Fusing frame 443
# Fusing frame 444
# Fusing frame 445
# Fusing frame 446
# Fusing frame 447
# Fusing frame 448
# Fusing frame 449
# Fusing frame 450
# Fusing frame 451
# Fusing frame 452
# Fusing frame 453
# Fusing frame 454
# Fusing frame 455
# Fusing frame 456
# Fusing frame 457
# Fusing frame 458
# Fusing frame 459
# Fusing frame 460
# Fusing frame 461
# Fusing frame 462
# Fusing frame 463
# Fusing frame 464
# Fusing frame 465
# Fusing frame 466
# Fusing frame 467
# Fusing frame 468
# Fusing frame 469
# Fusing frame 470
# Fusing frame 471
# Fusing frame 472
# Fusing frame 473
# Fusing frame 474
# Fusing frame 475
# Fusing frame 476
# Fusing frame 477
# Fusing frame 478
# Fusing frame 479
# Fusing frame 480
# Fusing frame 481
# Fusing frame 482
# Fusing frame 483
# Fusing frame 484
# Fusing frame 485
# Fusing frame 486
# Fusing frame 487
# Fusing frame 488
# Fusing frame 489
# Fusing frame 490
# Fusing frame 491
# Fusing frame 492
# Fusing frame 493
# Fusing frame 494
# Fusing frame 495
# Fusing frame 496
# Fusing frame 497
# Fusing frame 498
# Fusing frame 499
# Time:  1.6444971561431885 seconds
# FPS:  304.0443080927191

# %%
tsdf_obj.save_mesh(output_mesh_file)
tsdf_obj.save_point_cloud(output_pc_file)
# Out:
# Mesh saved to bunny_outputs/bunny_mesh.ply
# Point cloud saved to bunny_outputs/bunny_pc.ply

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Dataset

# %%
# show random dataset rgb images and depth images in one figure
fig, axs = plt.subplots(2, 5, figsize=(20, 5))
for i in range(5):
    idx = np.random.randint(frames_count)
    axs[0, i].imshow(frame_color_imgs[idx])
    axs[0, i].set_title(f"RGB Image {idx}")
    axs[0, i].axis("off")
    axs[1, i].imshow(frame_depth_imgs[idx], cmap="gray")
    axs[1, i].set_title(f"Depth Image {idx}")
    axs[1, i].axis("off")
plt.suptitle("Random RGB and Depth Images")
plt.show()

# %% [markdown]
# ### Occupancy Dual Contouring

# %%
import torch

volume_origin = torch.tensor(tsdf_obj.volume_origin, device="cuda:0")
tsdf_tensor = torch.tensor(tsdf_obj.get_tsdf()[0], device="cuda:0")
voxel_size = tsdf_obj.voxel_size


def implicit_function(xyz):
    """
    Implicit function for the TSDF volume. Performs trilinear interpolation to get the value at the given point.
    """
    # world space to voxel grid space
    relative_xyz = (xyz - volume_origin) / voxel_size

    device = relative_xyz.device
    min_bound = torch.tensor([0, 0, 0], dtype=torch.float64, device=device)
    max_bound = torch.tensor([tsdf_tensor.shape[0] - 1, 
                              tsdf_tensor.shape[1] - 1, 
                              tsdf_tensor.shape[2] - 1], dtype=torch.float64, device=device)
    relative_xyz = torch.clamp(relative_xyz, min=min_bound, max=max_bound)
    

    interpolated_values = []
    
    # interpolation for each point in xyz
    for i in range(xyz.shape[0]):
        xyz_point = relative_xyz[i]
        lower_indices = torch.floor(xyz_point).long()
        fractional_part = xyz_point - lower_indices.float()

        # neighbors - 8 surrounding points for trilinear interpolation
        x0, y0, z0 = lower_indices
        x1, y1, z1 = x0 + 1, y0 + 1, z0 + 1

        # Fetch the values at the 8 surrounding points 
        values = []
        for j, k, l in [(x0, y0, z0), (x0, y0, z1), (x0, y1, z0), (x0, y1, z1),
                         (x1, y0, z0), (x1, y0, z1), (x1, y1, z0), (x1, y1, z1)]:
            if 0 <= j < tsdf_tensor.shape[0] and 0 <= k < tsdf_tensor.shape[1] and 0 <= l < tsdf_tensor.shape[2]:
                values.append(tsdf_tensor[j, k, l])
            else:
                values.append(torch.tensor(0.0, dtype=torch.float64)) 
                
        c000, c001, c010, c011, c100, c101, c110, c111 = values
        c00 = c000 * (1 - fractional_part[0]) + c100 * fractional_part[0]
        c01 = c001 * (1 - fractional_part[0]) + c101 * fractional_part[0]
        c10 = c010 * (1 - fractional_part[0]) + c110 * fractional_part[0]
        c11 = c011 * (1 - fractional_part[0]) + c111 * fractional_part[0]
        c0 = c00 * (1 - fractional_part[1]) + c10 * fractional_part[1]
        c1 = c01 * (1 - fractional_part[1]) + c11 * fractional_part[1]
        interpolated_value = c0 * (1 - fractional_part[2]) + c1 * fractional_part[2]
        
        interpolated_values.append(interpolated_value)
    
    return torch.stack(interpolated_values)


from occupancy_dual_contouring import occupancy_dual_contouring
odc = occupancy_dual_contouring("cuda:0")
vertices, triangles = odc.extract_mesh(implicit_function, min_coord=tsdf_obj.volume_bounds[:,0].flatten(), max_coord=tsdf_obj.volume_bounds[:,1].flatten(), num_grid=100)

# %%
import trimesh
mesh = trimesh.Trimesh(vertices.cpu().numpy(), triangles.cpu().numpy())
mesh.export("bunny_outputs/bunny_odc.ply")
print("ODC Mesh exported")
# Out:
# ODC Mesh exported

# %% [markdown]
# ### TSDF update

# %%
tsdf_obj_ = TSDF(
    volume_bounds,
    voxel_size=tsdf_voxel_size,
    trunc_margin=tsdf_trunc_margin,
    run_on_gpu=True,
    verbose=False
)
for i in range(frames_count):
    tsdf_obj_.add_frame(
        frame_color_imgs[i], frame_depth_imgs[i], frame_poses[i], cam_intrinsics
    )
    if i in [1, 10, 50, 100, 200, 500]:
        tsdf_obj_.save_mesh(f"bunny_outputs/tsdf_update/bunny_mesh_{i}.ply")
# Out:
# Mesh saved to bunny_outputs/tsdf_update/bunny_mesh_1.ply
# Mesh saved to bunny_outputs/tsdf_update/bunny_mesh_10.ply
# Mesh saved to bunny_outputs/tsdf_update/bunny_mesh_50.ply
# Mesh saved to bunny_outputs/tsdf_update/bunny_mesh_100.ply
# Mesh saved to bunny_outputs/tsdf_update/bunny_mesh_200.ply

# %% [markdown]
# ### Different hyperparameters

# %%
# changing the voxel size
voxel_sizes = [0.01, 0.02, 0.5]
for v in voxel_sizes:
    tsdf_obj_ = TSDF(
        volume_bounds,
        voxel_size=v,
        trunc_margin=tsdf_trunc_margin,
        run_on_gpu=True,
        verbose=False
    )
    start_time = time.time()
    tsdf_obj_.build_tsdf(
        frames_count, frame_color_imgs, frame_depth_imgs, frame_poses, cam_intrinsics
    )
    end_time = time.time()
    print("Time: ", end_time - start_time, "seconds for voxel size: ", v)
    tsdf_obj_.save_mesh(f"bunny_outputs/hyperparameters/voxel_size_{v}.ply")
# Out:
# Time:  3.710686683654785 seconds for voxel size:  0.01
# Mesh saved to bunny_outputs/hyperparameters/voxel_size_0.01.ply
# Time:  1.687652587890625 seconds for voxel size:  0.02
# Mesh saved to bunny_outputs/hyperparameters/voxel_size_0.02.ply
# Time:  1.3327889442443848 seconds for voxel size:  0.5
# Mesh saved to bunny_outputs/hyperparameters/voxel_size_0.5.ply

# %%
# changing the truncation margin
trunc_margins = [0.01, 0.1, 0.5]
for t in trunc_margins:
    tsdf_obj_ = TSDF(
        volume_bounds,
        voxel_size=tsdf_voxel_size,
        trunc_margin=t,
        run_on_gpu=True,
        verbose=False
    )
    start_time = time.time()
    tsdf_obj_.build_tsdf(
        frames_count, frame_color_imgs, frame_depth_imgs, frame_poses, cam_intrinsics
    )
    end_time = time.time()
    print("Time: ", end_time - start_time, "seconds for truncation margin: ", t)
    tsdf_obj_.save_mesh(f"bunny_outputs/hyperparameters/trunc_margin_{t}.ply")
# Out:
# Time:  1.6443212032318115 seconds for truncation margin:  0.01
# Mesh saved to bunny_outputs/hyperparameters/trunc_margin_0.01.ply
# Time:  1.644012451171875 seconds for truncation margin:  0.1
# Mesh saved to bunny_outputs/hyperparameters/trunc_margin_0.1.ply
# Time:  1.638268232345581 seconds for truncation margin:  0.5
# Mesh saved to bunny_outputs/hyperparameters/trunc_margin_0.5.ply

# %% [markdown]
# ## Nearest Pose Estimation

# %% [markdown]
# Creating the tsdf only on every 5th frame and then using the nearest pose estimation to get the tsdf for the intermediate frames.

# %%
train_frame_count = frames_count // 5
train_frame_color_imgs = frame_color_imgs[::5]
train_frame_depth_imgs = frame_depth_imgs[::5]
train_frame_poses = frame_poses[::5]

# %%
tsdf_obj_ = TSDF(
    volume_bounds,
    voxel_size=tsdf_voxel_size,
    trunc_margin=tsdf_trunc_margin,
    run_on_gpu=True,
)
start_time = time.time()
tsdf_obj_.build_tsdf(
    train_frame_count, train_frame_color_imgs, train_frame_depth_imgs, train_frame_poses, cam_intrinsics
)
end_time = time.time()
print("Time: ", end_time - start_time, "seconds")
print("FPS: ", frames_count / (end_time - start_time))
# Out:
# Volume dims:  [325 325 325]
# Using GPU:  NVIDIA GeForce RTX 3090
# Maximum number of threads per block: 1024
# Maximum block dimension: 1024, 1024, 64
# Maximum grid dimension: 2147483647, 65535, 65535
# Block size: (1024, 1, 1), Grid size: (33524, 1, 1)
# Fusing frame 0
# Fusing frame 1
# Fusing frame 2
# Fusing frame 3
# Fusing frame 4
# Fusing frame 5
# Fusing frame 6
# Fusing frame 7
# Fusing frame 8
# Fusing frame 9
# Fusing frame 10
# Fusing frame 11
# Fusing frame 12
# Fusing frame 13
# Fusing frame 14
# Fusing frame 15
# Fusing frame 16
# Fusing frame 17
# Fusing frame 18
# Fusing frame 19
# Fusing frame 20
# Fusing frame 21
# Fusing frame 22
# Fusing frame 23
# Fusing frame 24
# Fusing frame 25
# Fusing frame 26
# Fusing frame 27
# Fusing frame 28
# Fusing frame 29
# Fusing frame 30
# Fusing frame 31
# Fusing frame 32
# Fusing frame 33
# Fusing frame 34
# Fusing frame 35
# Fusing frame 36
# Fusing frame 37
# Fusing frame 38
# Fusing frame 39
# Fusing frame 40
# Fusing frame 41
# Fusing frame 42
# Fusing frame 43
# Fusing frame 44
# Fusing frame 45
# Fusing frame 46
# Fusing frame 47
# Fusing frame 48
# Fusing frame 49
# Fusing frame 50
# Fusing frame 51
# Fusing frame 52
# Fusing frame 53
# Fusing frame 54
# Fusing frame 55
# Fusing frame 56
# Fusing frame 57
# Fusing frame 58
# Fusing frame 59
# Fusing frame 60
# Fusing frame 61
# Fusing frame 62
# Fusing frame 63
# Fusing frame 64
# Fusing frame 65
# Fusing frame 66
# Fusing frame 67
# Fusing frame 68
# Fusing frame 69
# Fusing frame 70
# Fusing frame 71
# Fusing frame 72
# Fusing frame 73
# Fusing frame 74
# Fusing frame 75
# Fusing frame 76
# Fusing frame 77
# Fusing frame 78
# Fusing frame 79
# Fusing frame 80
# Fusing frame 81
# Fusing frame 82
# Fusing frame 83
# Fusing frame 84
# Fusing frame 85
# Fusing frame 86
# Fusing frame 87
# Fusing frame 88
# Fusing frame 89
# Fusing frame 90
# Fusing frame 91
# Fusing frame 92
# Fusing frame 93
# Fusing frame 94
# Fusing frame 95
# Fusing frame 96
# Fusing frame 97
# Fusing frame 98
# Fusing frame 99
# Time:  0.35935139656066895 seconds
# FPS:  1391.3957334950428

# %%
# randomly sampling a image
sample_image_rgb = frame_color_imgs[13]
sample_image_depth = frame_depth_imgs[13]
true_pose = frame_poses[13]

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.imshow(sample_image_rgb)
plt.title("RGB Image")
plt.axis("off")
plt.subplot(1, 2, 2)
plt.imshow(sample_image_depth, cmap="gray")
plt.title("Depth Image")
plt.axis("off")
plt.suptitle("Sample RGB and Depth Images")
plt.show()

# %%
# alignment loss
def compute_alignment_loss(fixed_tsdf, moving_tsdf):
    mask = moving_tsdf != 1
    fixed_tsdf = fixed_tsdf[mask]
    moving_tsdf = moving_tsdf[mask]
    alignment_loss = np.sum(np.abs(fixed_tsdf - moving_tsdf))
    return alignment_loss

# %%
tsdf_grid, _, _ = tsdf_obj_.get_tsdf()

# %%
# iterate over all frames and find the best pose
min_loss = np.inf
best_pose = np.eye(4, 4)
min_index = 0
index = 0
for pose in train_frame_poses:
    tsdf_obj_sample_image = TSDF(
        volume_bounds,
        voxel_size=tsdf_voxel_size,
        trunc_margin=tsdf_trunc_margin,
        run_on_gpu=True,
        verbose=False
    )
    tsdf_obj_sample_image.build_tsdf(
        1, [sample_image_rgb], [sample_image_depth], [pose], cam_intrinsics
    )
    
    tsdf_grid_sample_image, _, color_grid_sample_image = tsdf_obj_sample_image.get_tsdf()
    
    loss = compute_alignment_loss(tsdf_grid, tsdf_grid_sample_image)
    
    if loss < min_loss:
        min_loss = loss
        min_pose = pose
        min_index = index
    
    index += 1

# %%
# show the nearest pose
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.imshow(frame_color_imgs[min_index])
# plt.imshow(cv2.flip(frame_color_imgs[min_index], 1))
plt.title("RGB Image")
plt.axis("off")
plt.subplot(1, 2, 2)
plt.imshow(frame_depth_imgs[min_index], cmap="gray")
# plt.imshow(cv2.flip(frame_depth_imgs[min_index], 1), cmap="gray")
plt.title("Depth Image")
plt.axis("off")
plt.suptitle("Nearest Pose")
plt.show()

# %%
# show true image and the nearest image
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.imshow(sample_image_rgb)
plt.title("Sampled RGB Image")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(frame_color_imgs[min_index])
plt.title("Nearest RGB Image")
plt.axis("off")
plt.suptitle("Sampled Image and Nearest Image")
plt.show()

# %%
print("True Pose:")
print(true_pose)
print("Estimated Pose:")
print(frame_poses[min_index])
print("Loss:", min_loss)
# Out:
# True Pose:
# [[-4.91818972e-02 -4.36584919e-08 -9.98789847e-01  3.05629706e+00]
#  [-9.98789847e-01  2.14980900e-09  4.91818972e-02 -1.50496751e-01]
#  [ 0.00000000e+00 -1.00000000e+00  4.37113883e-08  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Estimated Pose:
# [[-2.69200071e-03 -4.37112284e-08 -9.99996364e-01  3.05998898e+00]
#  [-9.99996364e-01  1.17671081e-10  2.69200071e-03 -8.23765621e-03]
#  [ 0.00000000e+00 -1.00000000e+00  4.37113883e-08  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Loss: 1052.379
